#  75%|███████▍  | 170M/228M [00:12<00:02, 22.4MB/s]
#  76%|███████▌  | 173M/228M [00:12<00:02, 22.8MB/s]
#  77%|███████▋  | 176M/228M [00:12<00:02, 22.8MB/s]
#  79%|███████▊  | 179M/228M [00:12<00:02, 23.1MB/s]
#  80%|███████▉  | 182M/228M [00:13<00:02, 22.9MB/s]
#  81%|████████  | 185M/228M [00:13<00:01, 22.7MB/s]
#  83%|████████▎ | 188M/228M [00:13<00:01, 22.7MB/s]
#  84%|████████▍ | 191M/228M [00:13<00:01, 22.6MB/s]
#  85%|████████▌ | 194M/228M [00:13<00:01, 22.0MB/s]
#  86%|████████▋ | 197M/228M [00:13<00:01, 21.7MB/s]
#  88%|████████▊ | 200M/228M [00:14<00:01, 21.1MB/s]
#  89%|████████▉ | 203M/228M [00:14<00:01, 20.9MB/s]
#  90%|█████████ | 206M/228M [00:14<00:01, 20.8MB/s]
#  92%|█████████▏| 209M/228M [00:14<00:00, 20.9MB/s]
#  93%|█████████▎| 212M/228M [00:14<00:00, 21.0MB/s]
#  94%|█████████▍| 215M/228M [00:14<00:00, 20.4MB/s]
#  95%|█████████▌| 217M/228M [00:14<00:00, 20.4MB/s]
#  96%|█████████▌| 219M/228M [00:15<00:00, 19.9MB/s]
#  97%|█████████▋| 221M/228M [00:15<00:00, 20.1MB/s]
#  98%|█████████▊| 223M/228M [00:15<00:00, 20.1MB/s]
#  99%|█████████▉| 225M/228M [00:15<00:00, 20.3MB/s]
# 100%|█████████▉| 227M/228M [00:15<00:00, 20.4MB/s]
# 100%|██████████| 228M/228M [00:15<00:00, 15.5MB/s]

# %%
import zipfile
import os

zip_file_path = 'the-movies-dataset.zip'

extract_to = 'data'

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

os.remove(zip_file_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pa
from scipy.linalg import svd, diagsvd

# %%
import pandas as pd
df = pd.read_csv('data/ratings_small.csv')
df.head(2)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179

# %%
ratings = df[['userId', 'movieId', 'rating']]
rating_matrix = ratings.pivot(index='userId', columns='movieId', values='rating').fillna(0)

def decompose_matrix_and_predict(matrix, i, j):
    """
    Decomposes the matrix using SVD and predicts the value at cell (i, j).
    """
    U, sigma, VT = svd(matrix, full_matrices=False)
    sigma[-170:] = 0  # Zero out the last 170 singular values
    Sigma = np.diag(sigma)
    
    B_approx = np.dot(U, np.dot(Sigma, VT))
    
    return B_approx[i, j]

numero_de_experimentos = 100
erros = []

# Get indices of non-zero entries
non_zero_indices = np.argwhere(rating_matrix.values != 0)
# Randomly sample indices for the experiments
sampled_indices = non_zero_indices[np.random.choice(non_zero_indices.shape[0], numero_de_experimentos, replace=True)]

for idx in sampled_indices:
    i, j = idx

    original_value = rating_matrix.iloc[i, j]

    matrix_corrupted = rating_matrix.copy()
    matrix_corrupted.iloc[i, j] = np.random.uniform(0, 5)
    
    predicted_value = decompose_matrix_and_predict(matrix_corrupted.values, i, j)
    
    error = original_value - predicted_value
    erros.append(error)

plt.hist(erros, bins=20, edgecolor='black')
plt.title('Error Distribution')
plt.xlabel('Prediction Error')
plt.ylabel('Count')
plt.show()
